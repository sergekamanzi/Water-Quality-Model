# %% [markdown]
# # Excercise - Creating our own custom Model

# %% [markdown]
# This is a notebook that provides a quick overview of how to create your own custom model. You will be creating a simple model.
# You will be utilizing Keras and Tensorflow

# %% [markdown]
# ## Water Quality Dataset
#
# This dataset contains water quality measurements and assessments related to potability, which is the suitability of water for human consumption. The dataset's primary objective is to provide insights into water quality parameters and assist in determining whether the water is potable or not. Each row in the dataset represents a water sample with specific attributes, and the "Potability" column indicates whether the water is suitable for consumption.
#
# https://www.kaggle.com/datasets/uom190346a/water-quality-and-potability?select=water_potability.csv

# %%
import tensorflow as tf
import numpy as np
import pandas as pd
# %matplotlib inline
import seaborn as sns
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.preprocessing import StandardScaler
from sklearn.model_selection import train_test_split
from tensorflow.keras.layers import Input
from tensorflow.keras.regularizers import l2
from sklearn.datasets import make_classification
from tensorflow.keras.callbacks import EarlyStopping
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, Dropout
from tensorflow.keras.optimizers import Adam, RMSprop, SGD
from matplotlib import pyplot
import keras
from imblearn.over_sampling import SMOTE
from sklearn.utils.class_weight import compute_class_weight
from sklearn.metrics import recall_score, precision_score, f1_score,confusion_matrix, accuracy_score

# %%
#LOAD THE DATA
df = pd.read_csv("/content/water_potability.csv")
df.head()
# Out:
#          ph    Hardness        Solids  Chloramines     Sulfate  Conductivity  \
# 0       NaN  204.890455  20791.318981     7.300212  368.516441    564.308654
# 1  3.716080  129.422921  18630.057858     6.635246         NaN    592.885359
# 2  8.099124  224.236259  19909.541732     9.275884         NaN    418.606213
# 3  8.316766  214.373394  22018.417441     8.059332  356.886136    363.266516
# 4  9.092223  181.101509  17978.986339     6.546600  310.135738    398.410813
#
#    Organic_carbon  Trihalomethanes  Turbidity  Potability
# 0       10.379783        86.990970   2.963135           0
# 1       15.180013        56.329076   4.500656           0
# 2       16.868637        66.420093   3.055934           0
# 3       18.436524       100.341674   4.628771           0
# 4       11.558279        31.997993   4.075075           0

# %%
df.isnull().sum()
# Out:
# ph                 491
# Hardness             0
# Solids               0
# Chloramines          0
# Sulfate            781
# Conductivity         0
# Organic_carbon       0
# Trihalomethanes    162
# Turbidity            0
# Potability           0
# dtype: int64

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3276 entries, 0 to 3275
# Data columns (total 10 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   ph               2785 non-null   float64
#  1   Hardness         3276 non-null   float64
#  2   Solids           3276 non-null   float64
#  3   Chloramines      3276 non-null   float64
#  4   Sulfate          2495 non-null   float64
#  5   Conductivity     3276 non-null   float64
#  6   Organic_carbon   3276 non-null   float64
#  7   Trihalomethanes  3114 non-null   float64
#  8   Turbidity        3276 non-null   float64
#  9   Potability       3276 non-null   int64
# dtypes: float64(9), int64(1)
# memory usage: 256.1 KB

# %%
df.describe()
# Out:
#                 ph     Hardness        Solids  Chloramines      Sulfate  \
# count  2785.000000  3276.000000   3276.000000  3276.000000  2495.000000
# mean      7.080795   196.369496  22014.092526     7.122277   333.775777
# std       1.594320    32.879761   8768.570828     1.583085    41.416840
# min       0.000000    47.432000    320.942611     0.352000   129.000000
# 25%       6.093092   176.850538  15666.690297     6.127421   307.699498
# 50%       7.036752   196.967627  20927.833607     7.130299   333.073546
# 75%       8.062066   216.667456  27332.762127     8.114887   359.950170
# max      14.000000   323.124000  61227.196008    13.127000   481.030642
#
#        Conductivity  Organic_carbon  Trihalomethanes    Turbidity   Potability
# count   3276.000000     3276.000000      3114.000000  3276.000000  3276.000000
# mean     426.205111       14.284970        66.396293     3.966786     0.390110
# std       80.824064        3.308162        16.175008     0.780382     0.487849
# min      181.483754        2.200000         0.738000     1.450000     0.000000
# 25%      365.734414       12.065801        55.844536     3.439711     0.000000
# 50%      421.884968       14.218338        66.622485     3.955028     0.000000
# 75%      481.792304       16.557652        77.337473     4.500320     1.000000
# max      753.342620       28.300000       124.000000     6.739000     1.000000

# %%
df.fillna(df.mean(), inplace=True)
df.isnull().sum()
# Out:
# ph                 0
# Hardness           0
# Solids             0
# Chloramines        0
# Sulfate            0
# Conductivity       0
# Organic_carbon     0
# Trihalomethanes    0
# Turbidity          0
# Potability         0
# dtype: int64

# %%
df.Potability.value_counts()
# Out:
# Potability
# 0    1998
# 1    1278
# Name: count, dtype: int64

# %%
sns.distplot(df['ph'])
plt.show()
# Out:
# <ipython-input-299-48fab1294798>:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df['ph'])

# %%
# Split into features (X) and target (Y)
X_data = df.drop(columns=["Potability"])
Y_data = df["Potability"]

# %%
# Normalize features
scaler = StandardScaler()
X_scaled = scaler.fit_transform(X_data)

# %% [markdown]
# Plot the Data Appropriately

# %%
# generate 2d classification dataset
X, y = make_classification(n_samples=100, n_features=2, n_informative=2, n_redundant=0, n_clusters_per_class=1, random_state=42)
# Plot the dataset
plt.figure(figsize=(8, 6))
plt.scatter(X[:, 0], X[:, 1], c=y, cmap=plt.cm.Paired, edgecolors='k')
plt.title('2D Classification Dataset')
plt.xlabel('Features (X)')
plt.ylabel('Features (Y)')
plt.colorbar(label='Class')
plt.grid(True)
plt.show()

# %%
# Split into training (70%), validation (15%), and testing (15%)
X_train, X_temp, Y_train, Y_temp = train_test_split(
    X_scaled, Y_data, test_size=0.3, random_state=42, stratify=Y_data
)
X_val, X_test, Y_val, Y_test = train_test_split(
    X_temp, Y_temp, test_size=0.5, random_state=42, stratify=Y_temp
)

# %% [markdown]
# # Each Memeber Defines their model Here

# %%
def build_model_5():
    model = Sequential([
        Input(shape=(X_train.shape[1],)),
        Dense(128, activation="relu", kernel_regularizer=l2(0.005)),
        Dense(64, activation="relu",  kernel_regularizer=l2(0.005)),
        # Output layer for binary classification
        Dense(1, activation='sigmoid')
    ])

    # Compile the model using RMSprop optimizer and binary_crossentropy loss
    model.compile(optimizer=RMSprop(learning_rate=0.001),
                  loss="binary_crossentropy",
                  metrics=["accuracy"])

    return model

# %%
model_5 = build_model_5()
# Calculate class weights for weighted loss
class_weights = compute_class_weight('balanced', classes=np.unique(Y_train), y=Y_train)
class_weights_dict = {0: class_weights[0], 1: class_weights[1]}

# %%
# Early stopping callback
early_stopping = EarlyStopping(monitor='val_loss', patience=10, restore_best_weights=True)

history_1 = model_5.fit(X_train, Y_train, validation_data=(X_val, Y_val),
                        epochs=430, batch_size=64, callbacks=[early_stopping],
                        verbose=1, class_weight=class_weights_dict)
# Out:
# Epoch 1/430
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 1s 12ms/step - accuracy: 0.5196 - loss: 1.1453 - val_accuracy: 0.5906 - val_loss: 1.0092
# Epoch 2/430
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.6242 - loss: 0.9715 - val_accuracy: 0.6293 - val_loss: 0.8973
# Epoch 3/430
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.6455 - loss: 0.8693 - val_accuracy: 0.6171 - val_loss: 0.8312
# Epoch 4/430
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.6506 - loss: 0.8025 - val_accuracy: 0.6090 - val_loss: 0.7825
# Epoch 5/430
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.6765 - loss: 0.7507 - val_accuracy: 0.5540 - val_loss: 0.7785
# Epoch 6/430
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.6425 - loss: 0.7244 - val_accuracy: 0.6273 - val_loss: 0.7264
# Epoch 7/430
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - accuracy: 0.6859 - loss: 0.6982 - val_accuracy: 0.6130 - val_loss: 0.7299
# Epoch 8/430
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.6815 - loss: 0.6898 - val_accuracy: 0.6293 - val_loss: 0.7160
# Epoch 9/430
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - accuracy: 0.6860 - loss: 0.6730 - val_accuracy: 0.6599 - val_loss: 0.6936
# Epoch 10/430
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.6932 - loss: 0.6601 - val_accuracy: 0.6599 - val_loss: 0.6896
# Epoch 11/430
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.6795 - loss: 0.6627 - val_accuracy: 0.6069 - val_loss: 0.7051
# Epoch 12/430
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.6720 - loss: 0.6570 - val_accuracy: 0.6293 - val_loss: 0.6937
# Epoch 13/430
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.6624 - loss: 0.6617 - val_accuracy: 0.6415 - val_loss: 0.6846
# Epoch 14/430
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.6755 - loss: 0.6405 - val_accuracy: 0.6354 - val_loss: 0.6792
# Epoch 15/430
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.6717 - loss: 0.6539 - val_accuracy: 0.6456 - val_loss: 0.6832
# Epoch 16/430
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.6860 - loss: 0.6352 - val_accuracy: 0.5804 - val_loss: 0.7106
# Epoch 17/430
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.6677 - loss: 0.6453 - val_accuracy: 0.6151 - val_loss: 0.6853
# Epoch 18/430
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.6734 - loss: 0.6308 - val_accuracy: 0.6314 - val_loss: 0.6791
# Epoch 19/430
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.6686 - loss: 0.6416 - val_accuracy: 0.6110 - val_loss: 0.6884
# Epoch 20/430
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.6816 - loss: 0.6220 - val_accuracy: 0.6253 - val_loss: 0.6837
# Epoch 21/430
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.6646 - loss: 0.6450 - val_accuracy: 0.6293 - val_loss: 0.6846
# Epoch 22/430
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.6792 - loss: 0.6282 - val_accuracy: 0.5866 - val_loss: 0.7009
# Epoch 23/430
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.6898 - loss: 0.6247 - val_accuracy: 0.6578 - val_loss: 0.6652
# Epoch 24/430
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.6865 - loss: 0.6265 - val_accuracy: 0.6599 - val_loss: 0.6621
# Epoch 25/430
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.6622 - loss: 0.6343 - val_accuracy: 0.6436 - val_loss: 0.6700
# Epoch 26/430
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.7073 - loss: 0.6117 - val_accuracy: 0.6395 - val_loss: 0.6597
# Epoch 27/430
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.6961 - loss: 0.6203 - val_accuracy: 0.6456 - val_loss: 0.6609
# Epoch 28/430
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.7033 - loss: 0.6148 - val_accuracy: 0.6273 - val_loss: 0.6813
# Epoch 29/430
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.6764 - loss: 0.6219 - val_accuracy: 0.6171 - val_loss: 0.6876
# Epoch 30/430
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.7035 - loss: 0.6148 - val_accuracy: 0.6191 - val_loss: 0.6817
# Epoch 31/430
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.6897 - loss: 0.6219 - val_accuracy: 0.6354 - val_loss: 0.6744
# Epoch 32/430
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.6933 - loss: 0.6063 - val_accuracy: 0.6497 - val_loss: 0.6675
# Epoch 33/430
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.7045 - loss: 0.6106 - val_accuracy: 0.6191 - val_loss: 0.6830
# Epoch 34/430
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.6841 - loss: 0.6136 - val_accuracy: 0.6212 - val_loss: 0.6835
# Epoch 35/430
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.6965 - loss: 0.6163 - val_accuracy: 0.6354 - val_loss: 0.6692
# Epoch 36/430
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.6908 - loss: 0.6066 - val_accuracy: 0.6314 - val_loss: 0.6713

# %% [markdown]
# # Start the training Process

# %%
# Step 6: Evaluate the model
_, train_acc = model_5.evaluate(X_train, Y_train, verbose=0)
_, test_acc = model_5.evaluate(X_test, Y_test, verbose=0)
print(f'Train Accuracy: {train_acc:.3f}, Test Accuracy: {test_acc:.3f}')

# Generate predictions
y_pred_prob = model_5.predict(X_test)
y_pred = (y_pred_prob > 0.5).astype(int)

# Calculate F1 score
f1 = f1_score(Y_test, y_pred)
print(f'Test Accuracy: {test_acc:.3f}, F1 Score: {f1:.4f}')

recall = recall_score(Y_test, y_pred)
precision = precision_score(Y_test, y_pred)

recall, precision
# Out:
# Train Accuracy: 0.708, Test Accuracy: 0.681
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step
# Test Accuracy: 0.681, F1 Score: 0.5768
# (0.5572916666666666, 0.5977653631284916)

# %%
# Step 7: Plot training history
plt.plot(history_1.history['loss'], label='train')
plt.plot(history_1.history['val_loss'], label='test')
plt.title('Training and Validation Loss')
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.legend()
plt.show()
pyplot.show()

# %%
# Compute and plot confusion matrix
conf_matrix = confusion_matrix(Y_test, y_pred)
plt.figure(figsize=(6, 5))
sns.heatmap(conf_matrix, annot=True, fmt="d", cmap="Blues",
            xticklabels=["Not Potable", "Potable"],
            yticklabels=["Not Potable", "Potable"])
plt.xlabel("Predicted Label")
plt.ylabel("True Label")
plt.title("Confusion Matrix")
plt.show()
